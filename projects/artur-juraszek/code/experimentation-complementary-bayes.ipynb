# %% [markdown]
# # Complement Naive Bayes approach - manual experimentation

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import common

import sklearn.naive_bayes

# %% [markdown]
# ## 1-X Occurence-counting vector representation

# %% [markdown]
# ### 1-1 "Dirty" data

# %% [markdown]
# #### All classes at once prediction on randomly downsampled training set

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('random_downsampling', 'count', None)
random_downsample_all_at_once_classifier = sklearn.naive_bayes.ComplementNB(fit_prior=False)
random_downsample_all_at_once_classifier.fit(train_as_vec, train_targets)
# Out:
# ComplementNB(alpha=1.0, class_prior=None, fit_prior=False, norm=False)

# %%
common.display_classifier_performance(random_downsample_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.44657295791472595
# [[0.81805657 0.09632975 0.01840866 0.02135558 0.04584944]
#  [0.49486388 0.26653127 0.08420888 0.0850291  0.06936687]
#  [0.28861151 0.17919155 0.18202925 0.20677475 0.14339293]
#  [0.17839576 0.06425506 0.10848067 0.33339947 0.31546904]
#  [0.15018279 0.02001024 0.02690256 0.17005616 0.63284824]]

# %% [markdown]
# #### All classes at once on full training set, with **no weights**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'count', None)
full_all_at_once_classifier = sklearn.naive_bayes.ComplementNB(fit_prior=False)
full_all_at_once_classifier.fit(train_as_vec, train_targets)
# Out:
# /home/asgavar/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# ComplementNB(alpha=1.0, class_prior=None, fit_prior=False, norm=False)

# %%
common.display_classifier_performance(full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.44593322174022365
# [[0.69432431 0.05710131 0.08580504 0.02552719 0.13724214]
#  [0.36671484 0.10463618 0.2913721  0.10408936 0.13318752]
#  [0.15583514 0.04224793 0.34588137 0.22030838 0.23572718]
#  [0.08465001 0.01624913 0.14590796 0.26206414 0.49112877]
#  [0.05182706 0.00795641 0.03585242 0.081604   0.82276011]]

# %% [markdown]
# #### All classes at once on full training set, **with weights**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'count', None)
weighted_full_all_at_once_classifier = sklearn.naive_bayes.ComplementNB(fit_prior=True)
weighted_full_all_at_once_classifier.fit(train_as_vec, train_targets)
# Out:
# ComplementNB(alpha=1.0, class_prior=None, fit_prior=True, norm=False)

# %%
common.display_classifier_performance(weighted_full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.44593322174022365
# [[0.69432431 0.05710131 0.08580504 0.02552719 0.13724214]
#  [0.36671484 0.10463618 0.2913721  0.10408936 0.13318752]
#  [0.15583514 0.04224793 0.34588137 0.22030838 0.23572718]
#  [0.08465001 0.01624913 0.14590796 0.26206414 0.49112877]
#  [0.05182706 0.00795641 0.03585242 0.081604   0.82276011]]

# %% [markdown]
# ### 1-2 Data with stop-words removal applied

# %% [markdown]
# #### All classes at once prediction on randomly downsampled training set

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset(
    'random_downsampling', 'count', 'stop_words')
stop_words_removal_random_downsample_all_at_once_classifier = sklearn.naive_bayes.ComplementNB(fit_prior=False)
stop_words_removal_random_downsample_all_at_once_classifier.fit(train_as_vec, train_targets)
# Out:
# ComplementNB(alpha=1.0, class_prior=None, fit_prior=False, norm=False)

# %%
common.display_classifier_performance(
    stop_words_removal_random_downsample_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.44575722470251317
# [[0.79157258 0.10941865 0.02009262 0.02104941 0.05786674]
#  [0.46658595 0.28641175 0.08377924 0.07479592 0.08842714]
#  [0.25733733 0.19717024 0.17937015 0.19484849 0.17127379]
#  [0.14928101 0.07857225 0.11456887 0.32073225 0.33684562]
#  [0.12030872 0.02733968 0.03395383 0.16769838 0.65069939]]

# %% [markdown]
# #### All classess at once, full training set with **no weights**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'count', 'stop_words')
stop_words_full_all_at_once_classifier = sklearn.naive_bayes.ComplementNB(fit_prior=False)
stop_words_full_all_at_once_classifier.fit(train_as_vec, train_targets)
# Out:
# /home/asgavar/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# ComplementNB(alpha=1.0, class_prior=None, fit_prior=False, norm=False)

# %%
common.display_classifier_performance(
    stop_words_full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.43944620517860444
# [[0.67928355 0.06915688 0.08515443 0.02426423 0.14214092]
#  [0.35413819 0.12271999 0.27723314 0.09651213 0.14939656]
#  [0.14924692 0.05373762 0.31915147 0.21487111 0.26299288]
#  [0.07842605 0.02205537 0.13725081 0.26162554 0.50064224]
#  [0.04973861 0.01061885 0.038325   0.08686706 0.81445047]]

# %% [markdown]
# #### All classes at once on full training set, **with weights**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'count', 'stop_words')
weighted_stop_words_full_all_at_once_classifier = sklearn.naive_bayes.ComplementNB(fit_prior=True)
weighted_stop_words_full_all_at_once_classifier.fit(train_as_vec, train_targets)
# Out:
# ComplementNB(alpha=1.0, class_prior=None, fit_prior=True, norm=False)

# %%
common.display_classifier_performance(
    weighted_stop_words_full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.43944620517860444
# [[0.67928355 0.06915688 0.08515443 0.02426423 0.14214092]
#  [0.35413819 0.12271999 0.27723314 0.09651213 0.14939656]
#  [0.14924692 0.05373762 0.31915147 0.21487111 0.26299288]
#  [0.07842605 0.02205537 0.13725081 0.26162554 0.50064224]
#  [0.04973861 0.01061885 0.038325   0.08686706 0.81445047]]

# %% [markdown]
# ## 2-X Binary vector representation (a given word either is or is not contained by a sample)

# %% [markdown]
# ### 2-1 "Dirty" data

# %% [markdown]
# #### All classes at once, randomly downsampled dataset

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('random_downsampling', 'binary', None)
binary_random_downsample_all_at_once_classifier = sklearn.naive_bayes.ComplementNB(fit_prior=False)
binary_random_downsample_all_at_once_classifier.fit(train_as_vec, train_targets)
# Out:
# ComplementNB(alpha=1.0, class_prior=None, fit_prior=False, norm=False)

# %%
common.display_classifier_performance(binary_random_downsample_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.45126333655995926
# [[0.83045658 0.08496307 0.01569138 0.01756669 0.05132229]
#  [0.51704878 0.24911143 0.07854548 0.07436629 0.08092802]
#  [0.30059731 0.15059631 0.16928939 0.19859901 0.18091798]
#  [0.16711745 0.04638728 0.09052935 0.31854969 0.37741622]
#  [0.12236626 0.01238498 0.01934353 0.15699564 0.68890959]]

# %% [markdown]
# #### All classes at once, full dataset with **no weigths**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'binary', None)
binary_full_all_at_once_classifier = sklearn.naive_bayes.ComplementNB(fit_prior=False)
binary_full_all_at_once_classifier.fit(train_as_vec, train_targets)
# Out:
# /home/asgavar/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# ComplementNB(alpha=1.0, class_prior=None, fit_prior=False, norm=False)

# %%
common.display_classifier_performance(binary_full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.4309069494630018
# [[0.65922921 0.05036549 0.07650503 0.0251062  0.18879406]
#  [0.35288833 0.09389525 0.26157091 0.10865914 0.18298637]
#  [0.14204354 0.03633441 0.28404739 0.22366202 0.31391265]
#  [0.06367026 0.01186311 0.10433484 0.25850312 0.56162867]
#  [0.03244821 0.00482595 0.02149821 0.08236785 0.85885979]]

# %% [markdown]
# #### All classes at once, full dataset **with weights**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'binary', None)
weighted_binary_full_all_at_once_classifier = sklearn.naive_bayes.ComplementNB(fit_prior=True)
weighted_binary_full_all_at_once_classifier.fit(train_as_vec, train_targets)
# Out:
# ComplementNB(alpha=1.0, class_prior=None, fit_prior=True, norm=False)

# %%
common.display_classifier_performance(weighted_binary_full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.4309069494630018
# [[0.65922921 0.05036549 0.07650503 0.0251062  0.18879406]
#  [0.35288833 0.09389525 0.26157091 0.10865914 0.18298637]
#  [0.14204354 0.03633441 0.28404739 0.22366202 0.31391265]
#  [0.06367026 0.01186311 0.10433484 0.25850312 0.56162867]
#  [0.03244821 0.00482595 0.02149821 0.08236785 0.85885979]]

# %% [markdown]
# ### 2-2 Data with stop-words removal applied

# %% [markdown]
# #### All classes at once, randomly downsampled dataset

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset(
    'random_downsampling', 'binary', 'stop_words')
binary_stop_words_removal_random_downsample_all_at_once_classifier = sklearn.naive_bayes.ComplementNB(
    fit_prior=False)
binary_stop_words_removal_random_downsample_all_at_once_classifier.fit(train_as_vec, train_targets)

common.display_classifier_performance(
    binary_stop_words_removal_random_downsample_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.45561726752965886
# [[0.79597382 0.10670137 0.02066669 0.019442   0.05721612]
#  [0.46920283 0.28281842 0.08729446 0.07436629 0.08631801]
#  [0.24981644 0.1802036  0.18617665 0.20748914 0.17631417]
#  [0.13734479 0.06297058 0.10693512 0.34201485 0.35073466]
#  [0.10447979 0.0206593  0.02948111 0.17427721 0.67110259]]

# %% [markdown]
# #### All classes at once, full dataset with **no weights**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'binary', 'stop_words')
stop_words_binary_full_all_at_once_classifier = sklearn.naive_bayes.ComplementNB(fit_prior=False)
stop_words_binary_full_all_at_once_classifier.fit(train_as_vec, train_targets)

common.display_classifier_performance(stop_words_binary_full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# /home/asgavar/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# SCORE: 0.4402518419890787
# [[0.67836504 0.06536798 0.08668529 0.02476176 0.14481993]
#  [0.35269304 0.11307269 0.27969379 0.10131625 0.15322423]
#  [0.14162681 0.04786379 0.30657036 0.22485266 0.27908638]
#  [0.06824424 0.01745006 0.11940392 0.26667989 0.52822189]
#  [0.04051059 0.00784161 0.03097791 0.08409866 0.83657124]]

# %% [markdown]
# #### All classes at once, full dataset **with weights**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'binary', 'stop_words')
stop_words_binary_full_all_at_once_classifier = sklearn.naive_bayes.ComplementNB(fit_prior=True)
stop_words_binary_full_all_at_once_classifier.fit(train_as_vec, train_targets)

common.display_classifier_performance(stop_words_binary_full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.4402518419890787
# [[0.67836504 0.06536798 0.08668529 0.02476176 0.14481993]
#  [0.35269304 0.11307269 0.27969379 0.10131625 0.15322423]
#  [0.14162681 0.04786379 0.30657036 0.22485266 0.27908638]
#  [0.06824424 0.01745006 0.11940392 0.26667989 0.52822189]
#  [0.04051059 0.00784161 0.03097791 0.08409866 0.83657124]]

# %% [markdown]
# ## 3-X TF-IDF representation

# %% [markdown]
# ### 3-1 "Dirty" data

# %% [markdown]
# #### All classes at once, randomly downsampled dataset

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset(
    'random_downsampling', 'tf_idf', None)
tf_idf_random_downsample_all_at_once_classifier = sklearn.naive_bayes.ComplementNB(fit_prior=False)
tf_idf_random_downsample_all_at_once_classifier.fit(train_as_vec, train_targets)

common.display_classifier_performance(tf_idf_random_downsample_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.46848821943147045
# [[0.76493551 0.12346435 0.03088522 0.02728769 0.05342723]
#  [0.40319494 0.30012108 0.12842245 0.09178612 0.07647541]
#  [0.19189173 0.1777231  0.2484472  0.23122259 0.15071538]
#  [0.10235069 0.06184275 0.13689575 0.38313892 0.31577189]
#  [0.08084898 0.02197506 0.03920807 0.21216951 0.64579838]]

# %% [markdown]
# #### All classes at once, full dataset with **no weights**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'tf_idf', None)
tf_idf_full_all_at_once_classifier = sklearn.naive_bayes.ComplementNB(fit_prior=False)
tf_idf_full_all_at_once_classifier.fit(train_as_vec, train_targets)

common.display_classifier_performance(tf_idf_full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# /home/asgavar/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# SCORE: 0.3641274184211352
# [[0.48976233 0.02150867 0.07639022 0.09629148 0.3160473 ]
#  [0.19306331 0.02796547 0.17802601 0.25704019 0.34390501]
#  [0.05046336 0.01019983 0.14367075 0.32117556 0.4744905 ]
#  [0.01488111 0.00370722 0.03234161 0.24641026 0.7026598 ]
#  [0.0091927  0.00216792 0.00793434 0.06787676 0.91282828]]

# %% [markdown]
# #### All classes at once, full dataset **with weights**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'tf_idf', None)
weighted_tf_idf_full_all_at_once_classifier = sklearn.naive_bayes.ComplementNB(fit_prior=False)
weighted_tf_idf_full_all_at_once_classifier.fit(train_as_vec, train_targets)

common.display_classifier_performance(weighted_tf_idf_full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.3641274184211352
# [[0.48976233 0.02150867 0.07639022 0.09629148 0.3160473 ]
#  [0.19306331 0.02796547 0.17802601 0.25704019 0.34390501]
#  [0.05046336 0.01019983 0.14367075 0.32117556 0.4744905 ]
#  [0.01488111 0.00370722 0.03234161 0.24641026 0.7026598 ]
#  [0.0091927  0.00216792 0.00793434 0.06787676 0.91282828]]
