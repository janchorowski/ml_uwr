# %% [markdown]
# # Naive Bayes approach - manual experimentation

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import common

import sklearn.naive_bayes
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1-X Occurence-counting vector representation

# %% [markdown]
# ### 1-1 "Dirty" data

# %% [markdown]
# #### All classes at once prediction on randomly downsampled training set

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('random_downsampling', 'count', None)
random_downsample_all_at_once_classifier = sklearn.naive_bayes.MultinomialNB(fit_prior=False)
random_downsample_all_at_once_classifier.fit(train_as_vec, train_targets)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=False)

# %%
common.display_classifier_performance(random_downsample_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.4648028120970972
# [[0.72023422 0.18508171 0.03700869 0.01925064 0.03842474]
#  [0.36179354 0.38163496 0.14408468 0.0677655  0.04472132]
#  [0.19967059 0.23411982 0.28269799 0.182188   0.1013236 ]
#  [0.12058397 0.09424702 0.18730354 0.32739481 0.27047066]
#  [0.12041469 0.03793645 0.05346956 0.17612723 0.61205207]]

# %% [markdown]
# #### All classes at once on full training set, with **no weights**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'count', None)
full_all_at_once_classifier = sklearn.naive_bayes.MultinomialNB(fit_prior=False)
full_all_at_once_classifier.fit(train_as_vec, train_targets)
# Out:
# /home/asgavar/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=False)

# %%
common.display_classifier_performance(full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.46672030993726754
# [[0.64950821 0.14795821 0.08082973 0.03478893 0.08691492]
#  [0.28969261 0.24075304 0.26036011 0.10912784 0.1000664 ]
#  [0.13565376 0.09588633 0.35318397 0.23739408 0.17788185]
#  [0.06593636 0.02536576 0.17150346 0.34630687 0.39088754]
#  [0.05953621 0.01010667 0.04259021 0.14391745 0.74384946]]

# %% [markdown]
# #### All classes at once on full training set, **with weights**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'count', None)
weighted_full_all_at_once_classifier = sklearn.naive_bayes.MultinomialNB(fit_prior=True)
weighted_full_all_at_once_classifier.fit(train_as_vec, train_targets)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
common.display_classifier_performance(weighted_full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.44874789970764245
# [[0.59451185 0.12158904 0.08783344 0.03934326 0.15672242]
#  [0.25231418 0.1811897  0.27168691 0.12330586 0.17150334]
#  [0.09773183 0.05677376 0.32117556 0.24681999 0.27749886]
#  [0.03853424 0.01135141 0.12580541 0.3212544  0.50305454]
#  [0.02847    0.00346603 0.02497307 0.11748291 0.82560799]]

# %% [markdown]
# ### 1-2 Data with stop-words removal applied

# %% [markdown]
# #### All classes at once prediction on randomly downsampled training set

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset(
    'random_downsampling', 'count', 'stop_words')
stop_words_removal_random_downsample_all_at_once_classifier = sklearn.naive_bayes.MultinomialNB(fit_prior=False)
stop_words_removal_random_downsample_all_at_once_classifier.fit(train_as_vec, train_targets)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=False)

# %%
common.display_classifier_performance(
    stop_words_removal_random_downsample_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.46269847786216156
# [[0.69386505 0.19809407 0.03838647 0.02016916 0.04948525]
#  [0.33554662 0.39776589 0.14447526 0.06389876 0.05831348]
#  [0.17683012 0.24394261 0.28140813 0.17728653 0.12053261]
#  [0.09877923 0.10119153 0.19430027 0.3257344  0.27999457]
#  [0.09333993 0.04346444 0.06301107 0.18546564 0.61471892]]

# %% [markdown]
# #### All classess at once, full training set with **no weights**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'count', 'stop_words')
stop_words_full_all_at_once_classifier = sklearn.naive_bayes.MultinomialNB(fit_prior=False)
stop_words_full_all_at_once_classifier.fit(train_as_vec, train_targets)
# Out:
# /home/asgavar/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=False)

# %%
common.display_classifier_performance(
    stop_words_full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.4571609734256118
# [[0.60798347 0.15538291 0.09407172 0.03635807 0.10620383]
#  [0.25766512 0.23341015 0.27590517 0.1109245  0.12209507]
#  [0.11219812 0.09160002 0.34367869 0.242494   0.21002917]
#  [0.05026159 0.02514646 0.16439186 0.34871918 0.41148091]
#  [0.04378676 0.01105597 0.04554406 0.14759983 0.75201339]]

# %% [markdown]
# #### All classes at once on full training set, **with weights**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'count', 'stop_words')
weighted_stop_words_full_all_at_once_classifier = sklearn.naive_bayes.MultinomialNB(fit_prior=True)
weighted_stop_words_full_all_at_once_classifier.fit(train_as_vec, train_targets)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
common.display_classifier_performance(
    weighted_stop_words_full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.43167638269134356
# [[0.54211795 0.12197176 0.09992728 0.04148647 0.19449654]
#  [0.21169394 0.16509784 0.27809241 0.12814905 0.21696676]
#  [0.07352212 0.04923303 0.29470363 0.2509674  0.33157383]
#  [0.02584613 0.01016092 0.10965027 0.31620004 0.53814263]
#  [0.01835008 0.00340863 0.02399728 0.11398156 0.84026245]]

# %% [markdown]
# ### Stemmed data

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset(
    'random_downsampling', 'count', 'stem')
stemmed_random_down_all_at_once_classifier = sklearn.naive_bayes.MultinomialNB(fit_prior=False)
stemmed_random_down_all_at_once_classifier.fit(train_as_vec, train_targets)

common.display_classifier_performance(
    stemmed_random_down_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-5cb3963b07ca> in <module>
# ----> 1 train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset(
#       2     'random_downsampling', 'count', 'stem')
#       3 stemmed_random_down_all_at_once_classifier = sklearn.naive_bayes.MultinomialNB(fit_prior=False)
#       4 stemmed_random_down_all_at_once_classifier.fit(train_as_vec, train_targets)
#       5
#
# ~/kindle-reviews/common.py in load_dataset(sampling_method, vectorization, preprocessing)
#      50     train = pd.read_csv(train_name, header=0, index_col=0)
#      51     test = pd.read_csv(test_name, header=0, index_col=0)
# ---> 52
#      53     # print(train['reviewText'].values)
#      54     # print(train['reviewText'].index)
#
# ~/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py in transform(self, raw_documents)
# ...

# %%
train_as_vec

# %% [markdown]
# ## 2-X Binary vector representation (a given word either is or is not contained by a sample)

# %% [markdown]
# ### 2-1 "Dirty" data

# %% [markdown]
# #### All classes at once, randomly downsampled dataset

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('random_downsampling', 'binary', None)
binary_random_downsample_all_at_once_classifier = sklearn.naive_bayes.MultinomialNB(fit_prior=False)
binary_random_downsample_all_at_once_classifier.fit(train_as_vec, train_targets)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=False)

# %%
common.display_classifier_performance(binary_random_downsample_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.4685926034694793
# [[0.73378239 0.17448046 0.03379387 0.01576792 0.04217536]
#  [0.39093075 0.35359138 0.14670156 0.05475921 0.05401711]
#  [0.22076479 0.19443177 0.28267815 0.17200802 0.13011728]
#  [0.11912196 0.06813981 0.17375912 0.31747408 0.32150503]
#  [0.1010535  0.02446972 0.04447113 0.17456862 0.65543703]]

# %% [markdown]
# #### All classes at once, full dataset with **no weigths**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'binary', None)
binary_full_all_at_once_classifier = sklearn.naive_bayes.MultinomialNB(fit_prior=False)
binary_full_all_at_once_classifier.fit(train_as_vec, train_targets)
# Out:
# /home/asgavar/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=False)

# %%
common.display_classifier_performance(binary_full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.444433527700889
# [[0.6113131  0.10846186 0.10497914 0.04041486 0.13483103]
#  [0.27469437 0.13853845 0.31051049 0.12182166 0.15443503]
#  [0.11416268 0.03895382 0.32482686 0.25519417 0.26686246]
#  [0.04128072 0.00666256 0.12016625 0.346192   0.48569847]
#  [0.0303995  0.00255206 0.02371911 0.14203211 0.80129722]]

# %% [markdown]
# #### All classes at once, full dataset **with weights**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'binary', None)
weighted_binary_full_all_at_once_classifier = sklearn.naive_bayes.MultinomialNB(fit_prior=True)
weighted_binary_full_all_at_once_classifier.fit(train_as_vec, train_targets)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
common.display_classifier_performance(weighted_binary_full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.40775378819361807
# [[5.17968541e-01 8.10976310e-02 1.07351984e-01 4.44333882e-02
#   2.49148456e-01]
#  [2.04585400e-01 9.17080030e-02 2.93598406e-01 1.36624614e-01
#   2.73483576e-01]
#  [6.46121485e-02 2.00226222e-02 2.56960292e-01 2.62238803e-01
#   3.96166134e-01]
#  [1.76902432e-02 2.69426372e-03 7.57422279e-02 3.15625685e-01
#   5.88247580e-01]
#  [1.14047791e-02 8.16834743e-04 1.24953639e-02 1.18776602e-01
#   8.56506420e-01]]

# %% [markdown]
# ### 2-2 Data with stop-words removal applied

# %% [markdown]
# #### All classes at once, randomly downsampled dataset

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset(
    'random_downsampling', 'binary', 'stop_words')
binary_stop_words_removal_random_downsample_all_at_once_classifier = sklearn.naive_bayes.MultinomialNB(
    fit_prior=False)
binary_stop_words_removal_random_downsample_all_at_once_classifier.fit(train_as_vec, train_targets)

common.display_classifier_performance(
    binary_stop_words_removal_random_downsample_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.4728210876612122
# [[0.6873206  0.20540396 0.04095067 0.02036052 0.04596425]
#  [0.32753974 0.39718002 0.16185603 0.06007109 0.05335312]
#  [0.16680888 0.22407874 0.30424861 0.18695057 0.1179132 ]
#  [0.0882528  0.0836997  0.19427939 0.35241596 0.28135214]
#  [0.08006747 0.03499585 0.05963335 0.20236308 0.62294025]]

# %% [markdown]
# #### All classes at once, full dataset with **no weights**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'binary', 'stop_words')
stop_words_binary_full_all_at_once_classifier = sklearn.naive_bayes.MultinomialNB(fit_prior=False)
stop_words_binary_full_all_at_once_classifier.fit(train_as_vec, train_targets)

common.display_classifier_performance(stop_words_binary_full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# /home/asgavar/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# SCORE: 0.4467713956091398
# [[0.57170194 0.13146313 0.12526312 0.04764821 0.12392361]
#  [0.22966059 0.16630864 0.32988322 0.13619498 0.13795258]
#  [0.08898061 0.05478936 0.3409799  0.28019765 0.23505249]
#  [0.03454506 0.01199887 0.135204   0.3752441  0.44300797]
#  [0.02921619 0.00545292 0.03461613 0.15109235 0.7796224 ]]

# %% [markdown]
# #### All classes at once, full dataset **with weights**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'binary', 'stop_words')
stop_words_binary_full_all_at_once_classifier = sklearn.naive_bayes.MultinomialNB(fit_prior=True)
stop_words_binary_full_all_at_once_classifier.fit(train_as_vec, train_targets)

common.display_classifier_performance(stop_words_binary_full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.40739512272923817
# [[0.48662406 0.09189024 0.12656435 0.0540013  0.24092005]
#  [0.17388587 0.10119908 0.30918252 0.15466937 0.26106316]
#  [0.0509793  0.02381283 0.26209989 0.28505943 0.37804854]
#  [0.01421276 0.00369678 0.07758018 0.32489897 0.57961132]
#  [0.01015966 0.00118772 0.01490171 0.11159729 0.86215362]]

# %% [markdown]
# ## 3-X TF-IDF representation

# %% [markdown]
# ### 3-1 "Dirty" data

# %% [markdown]
# #### All classes at once, randomly downsampled dataset

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset(
    'random_downsampling', 'tf_idf', None)
tf_idf_random_downsample_all_at_once_classifier = sklearn.naive_bayes.MultinomialNB(fit_prior=False)
tf_idf_random_downsample_all_at_once_classifier.fit(train_as_vec, train_targets)

common.display_classifier_performance(tf_idf_random_downsample_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.47332274786856854
# [[0.57797849 0.30196334 0.06816181 0.02698151 0.02491485]
#  [0.21200641 0.4577198  0.23559739 0.06967933 0.02499707]
#  [0.09392177 0.22132042 0.42021709 0.20649693 0.05804378]
#  [0.05137898 0.07729822 0.26765108 0.43941562 0.1642561 ]
#  [0.05616732 0.03919041 0.09670882 0.33665071 0.47128274]]

# %% [markdown]
# #### All classes at once, full dataset with **no weights**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'tf_idf', None)
tf_idf_full_all_at_once_classifier = sklearn.naive_bayes.MultinomialNB(fit_prior=False)
tf_idf_full_all_at_once_classifier.fit(train_as_vec, train_targets)

common.display_classifier_performance(tf_idf_full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# /home/asgavar/.local/lib/python3.8/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# SCORE: 0.2419224931298535
# [[6.27272379e-02 8.41976348e-04 2.66370699e-02 1.49680432e-01
#   7.60113284e-01]
#  [1.06628130e-02 1.24985353e-03 3.20274968e-02 2.64422138e-01
#   6.91637699e-01]
#  [1.19064156e-03 3.96880519e-04 2.58369218e-02 2.55154486e-01
#   7.17421070e-01]
#  [2.19300536e-04 2.08857653e-04 3.36260821e-03 1.62741883e-01
#   8.33467350e-01]
#  [5.34254075e-04 2.86995991e-04 1.20979848e-03 4.09123823e-02
#   9.57056569e-01]]

# %% [markdown]
# #### All classes at once, full dataset **with weights**

# %%
train_as_vec, train_targets, test_as_vec, test_targets = common.load_dataset('full', 'tf_idf', None)
weighted_tf_idf_full_all_at_once_classifier = sklearn.naive_bayes.MultinomialNB(fit_prior=False)
weighted_tf_idf_full_all_at_once_classifier.fit(train_as_vec, train_targets)

common.display_classifier_performance(weighted_tf_idf_full_all_at_once_classifier, test_as_vec, test_targets)
# Out:
# SCORE: 0.2419224931298535
# [[6.27272379e-02 8.41976348e-04 2.66370699e-02 1.49680432e-01
#   7.60113284e-01]
#  [1.06628130e-02 1.24985353e-03 3.20274968e-02 2.64422138e-01
#   6.91637699e-01]
#  [1.19064156e-03 3.96880519e-04 2.58369218e-02 2.55154486e-01
#   7.17421070e-01]
#  [2.19300536e-04 2.08857653e-04 3.36260821e-03 1.62741883e-01
#   8.33467350e-01]
#  [5.34254075e-04 2.86995991e-04 1.20979848e-03 4.09123823e-02
#   9.57056569e-01]]
